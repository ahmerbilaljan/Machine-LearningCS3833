# %%
# !git config --global user.email "ahmerbilaljan@gmail.com"
# !git config --global user.name "ahmerbilaljan"

# %%
# !git clone "https://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@github.com/ahmerbilaljan/Machine-LearningCS3833"
# Out:
# Cloning into 'Machine-LearningCS3833'...
# ...

# %%
# !mkdir assigment3

# %%
# %cd /content/Machine-LearningCS3833
# Out:
# /content/Machine-LearningCS3833

# %%
# !mkdir assigment3

# %%
# !echo "this is a test file" >> readme.md

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cp '/content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb' '/content/Machine-LearningCS3833/assigment3'

# %%
# !git add .

# %%
# !git commit -m 'added readme file'
# Out:
# [main (root-commit) 1448f36] added readme file
#  2 files changed, 2 insertions(+)
#  create mode 100644 assigment3/Untitled0.ipynb
#  create mode 100644 readme.md

# %%
# !git push origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
